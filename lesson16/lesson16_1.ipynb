# %%
#1維list
import pandas as pd
sdata = [3000, 5000, 8000]

s1 = pd.Series(sdata)
s1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#1維dict
sdata = {'台北':35000, '桃園':71000, '台中':16000, '高雄':5000}
s2 = pd.Series(sdata)
s2.index
# Out:
# Index(['台北', '桃園', '台中', '高雄'], dtype='object')

# %%
#2維dict
sdata = {
    '台北': [35000, 36000, 37000],
    '桃園': [71000, 72000, 73000],
    '台中': [16000, 17000, 18000],
    '高雄': [5000, 6000, 7000]
}
df1 = pd.DataFrame(sdata)
df1.index
df1.columns
# Out:
# Index(['台北', '桃園', '台中', '高雄'], dtype='object')

# %%
#2維dict
sdata = [
    {'城市': '台北', '人口': 35000, '面積': 100},
    {'城市': '桃園', '人口': 71000, '面積': 200},
    {'城市': '台中', '人口': 16000, '面積': 150},
    {'城市': '高雄', '人口': 5000, '面積': 80}
]
df2 = pd.DataFrame(sdata)
df2
# Out:
#    城市     人口   面積
# 0  台北  35000  100
# 1  桃園  71000  200
# 2  台中  16000  150
# 3  高雄   5000   80

# %%
import pandas as pd

df3 = pd.read_csv('交通流量.csv', encoding='utf-8')
df3
# Out:
#       路線方向     路段   交流道         進出口     週六     週日   週2-4
# 0     國1南向  非主線資料   基隆端          進口  34246  31547  29403
# 1     國1南向  非主線資料    基隆          出口   9484   8123   9403
# 2     國1南向  非主線資料    基隆  進口1-尚仁路,基隆   2108   1997   2579
# 3     國1南向  非主線資料    基隆  進口2-麥金路,金山   6051   5398   5895
# 4     國1南向  非主線資料    八堵          進口  10785  11990   9027
# ..     ...    ...   ...         ...    ...    ...    ...
# 751  國10西向  非主線資料  燕巢系統          出口   4612   4647   3906
# 752  國10西向  非主線資料  燕巢系統     進口1-國3南   6515   8890   6517
# 753  國10西向  非主線資料  燕巢系統     進口2-國3北  10822  13415  11181
# 754  國10西向  非主線資料    嶺口          進口   5196   5680   4242
# 755  國10西向  非主線資料   旗山端          進口  12946  17106  10412
#
# [756 rows x 7 columns]

# %%
n_array = df3.values
list1 = n_array.tolist()
list1[:5]
# Out:
# [['國1南向', '非主線資料', '基隆端', '進口', '34246', '31547', '29403'],
#  ['國1南向', '非主線資料', '基隆', '出口', '9484', '8123', '9403'],
#  ['國1南向', '非主線資料', '基隆', '進口1-尚仁路,基隆', '2108', '1997', '2579'],
#  ['國1南向', '非主線資料', '基隆', '進口2-麥金路,金山', '6051', '5398', '5895'],
#  ['國1南向', '非主線資料', '八堵', '進口', '10785', '11990', '9027']]

# %%
df3.values.tolist()[:5]  # 顯示前5行數據
# Out:
# [['國1南向', '非主線資料', '基隆端', '進口', '34246', '31547', '29403'],
#  ['國1南向', '非主線資料', '基隆', '出口', '9484', '8123', '9403'],
#  ['國1南向', '非主線資料', '基隆', '進口1-尚仁路,基隆', '2108', '1997', '2579'],
#  ['國1南向', '非主線資料', '基隆', '進口2-麥金路,金山', '6051', '5398', '5895'],
#  ['國1南向', '非主線資料', '八堵', '進口', '10785', '11990', '9027']]

# %%
df3.to_numpy().tolist()
# Out:
# [['國1南向', '非主線資料', '基隆端', '進口', '34246', '31547', '29403'],
#  ['國1南向', '非主線資料', '基隆', '出口', '9484', '8123', '9403'],
#  ['國1南向', '非主線資料', '基隆', '進口1-尚仁路,基隆', '2108', '1997', '2579'],
#  ['國1南向', '非主線資料', '基隆', '進口2-麥金路,金山', '6051', '5398', '5895'],
#  ['國1南向', '非主線資料', '八堵', '進口', '10785', '11990', '9027'],
#  ['國1南向', '非主線資料', '大華系統', '進口', '26351', '26929', '21257'],
#  ['國1南向', '非主線資料', '五堵', '出口', '6424', '6179', '7415'],
#  ['國1南向', '非主線資料', '五堵', '進口', '9008', '7768', '10482'],
#  ['國1南向', '非主線資料', '汐止及汐止系統', '出口', '20996', '20160', '18920'],
#  ['國1南向', '非主線資料', '汐止及汐止系統', '進口1-國3北+汐止', '25599', '25599', '25599'],
#  ['國1南向', '非主線資料', '汐止及汐止系統', '進口2-國3南', '9198', '9899', '9954'],
#  ['國1南向', '非主線資料', '高架汐止端', '出口', '32505', '34285', '28529'],
#  ['國1南向', '非主線資料', '東湖', '進口', '20553', '18047', '20259'],
#  ['國1南向', '非主線資料', '內湖', '出口1-南京', '20150', '18260', '18795'],
#  ['國1南向', '非主線資料', '內湖', '出口2-成功', '8614', '7655', '9187'],
#  ['國1南向', '非主線資料', '內湖', '進口', '16774', '13915', '19929'],
#  ['國1南向', '非主線資料', '圓山', '出口', '16675', '14411', '16248'],
#  ['國1南向', '非主線資料', '圓山', '進口', '67091', '59975', '66319'],
#  ['國1南向', '非主線資料', '台北', '出口1-士林', '32521', '29262', '32571'],
#  ['國1南向', '非主線資料', '台北', '出口2-台北市區', '6587', '6238', '6576'],
#  ['國1南向', '非主線資料', '台北', '進口', '23876', '21345', '23967'],
#  ['國1南向', '非主線資料', '三重', '出口', '21904', '20266', '22386'],
#  ['國1南向', '非主線資料', '三重', '進口', '15722', '14479', '13560'],
#  ['國1南向', '非主線資料', '五股及五股轉接道', '出口', '39500', '39500', '39500'],
#  ['國1南向', '非主線資料', '五股及五股轉接道', '進口1-高架', '47053', '46185', '49825'],
#  ['國1南向', '非主線資料', '五股及五股轉接道', '進口2-新五路台64', '52189', '45951', '51101'],
#  ['國1南向', '非主線資料', '泰山轉接道', '出口', '41097', '36659', '33514'],
#  ['國1南向', '非主線資料', '林口', '出口1-文化一路', '26223', '25025', '28585'],
#  ['國1南向', '非主線資料', '林口', '出口2-文化北路', '15267', '12536', '19724'],
#  ['國1南向', '非主線資料', '林口', '進口1-文化一路', '15003', '12953', '17661'],
#  ['國1南向', '非主線資料', '林口', '進口2-文化北路', '18074', '15005', '22048'],
#  ['國1南向', '非主線資料', '桃園', '出口', '34305', '31006', '37091'],
#  ['國1南向', '非主線資料', '桃園', '進口1-桃園', '13015', '12003', '14779'],
#  ['國1南向', '非主線資料', '桃園', '進口2-南崁', '20164', '17006', '19678'],
#  ['國1南向', '非主線資料', '機場系統', '出口', '29430', '26659', '31591'],
#  ['國1南向', '非主線資料', '機場系統', '進口', '20782', '19215', '23121'],
#  ['國1南向', '非主線資料', '內壢', '出口', '27488', '25331', '29693'],
#  ['國1南向', '非主線資料', '內壢', '進口1-中壢', '12179', '10111', '14863'],
#  ['國1南向', '非主線資料', '內壢', '進口2-大園', '6905', '6340', '5856'],
#  ['國1南向', '非主線資料', '中壢', '出口', '14650', '12836', '15958'],
#  ['國1南向', '非主線資料', '中壢', '進口1-民族路,中環', '12106', '11222', '11070'],
#  ['國1南向', '非主線資料', '中壢', '進口2-新屋', '4670', '3726', '5000'],
#  ['國1南向', '非主線資料', '平鎮系統', '出口', '24952', '22575', '26270'],
#  ['國1南向', '非主線資料', '平鎮系統', '進口', '16242', '14378', '16679'],
#  ['國1南向', '非主線資料', '幼獅', '出口', '7574', '5974', '10601'],
#  ['國1南向', '非主線資料', '幼獅', '進口', '4583', '3407', '5944'],
#  ['國1南向', '非主線資料', '楊梅', '出口', '25574', '22528', '27809'],
#  ['國1南向', '非主線資料', '楊梅', '進口', '6412', '5625', '7093'],
#  ['國1南向', '非主線資料', '高架楊梅端', '進口', '41286', '36050', '32419'],
#  ['國1南向', '非主線資料', '湖口', '出口', '10667', '9414', '12403'],
#  ['國1南向', '非主線資料', '湖口', '進口', '14830', '13252', '19837'],
#  ['國1南向', '非主線資料', '竹北', '出口', '17877', '17091', '18901'],
#  ['國1南向', '非主線資料', '竹北', '進口', '20256', '16765', '24074'],
#  ['國1南向', '非主線資料', '新竹', '出口1-公道五/光復路', '22382', '22714', '23548'],
#  ['國1南向', '非主線資料', '新竹', '出口2-新安路', '6404', '6179', '14067'],
#  ['國1南向', '非主線資料', '新竹', '進口1-光復路', '19521', '14552', '16176'],
#  ['國1南向', '非主線資料', '新竹', '進口2-園區二路', '5549', '4451', '9338'],
#  ['國1南向', '非主線資料', '新竹系統', '出口1-國3南', '30845', '24315', '28432'],
#  ['國1南向', '非主線資料', '新竹系統', '出口2-國3北', '3133', '3049', '3705'],
#  ['國1南向', '非主線資料', '新竹系統', '進口', '19059', '15678', '11517'],
#  ['國1南向', '非主線資料', '頭份', '出口', '16771', '14332', '15686'],
#  ['國1南向', '非主線資料', '頭份', '進口', '7731', '7362', '6066'],
#  ['國1南向', '非主線資料', '頭屋', '出口', '7622', '6039', '5573'],
#  ['國1南向', '非主線資料', '頭屋', '進口', '2068', '1924', '1405'],
#  ['國1南向', '非主線資料', '苗栗', '出口', '6510', '4631', '3711'],
#  ['國1南向', '非主線資料', '苗栗', '進口', '6943', '6943', '5786'],
#  ['國1南向', '非主線資料', '銅鑼', '出口', '2856', '2361', '2195'],
#  ['國1南向', '非主線資料', '銅鑼', '進口', '3790', '4153', '3201'],
#  ['國1南向', '非主線資料', '三義', '出口', '6234', '5375', '4562'],
#  ['國1南向', '非主線資料', '三義', '進口', '4892', '5373', '3733'],
#  ['國1南向', '非主線資料', '后里', '出口', '3192', '2798', '1930'],
#  ['國1南向', '非主線資料', '后里', '進口', '11378', '10085', '11051'],
#  ['國1南向', '非主線資料', '台中系統', '出口', '5245', '4931', '3922'],
#  ['國1南向', '非主線資料', '台中系統', '進口', '25718', '25586', '28289'],
#  ['國1南向', '非主線資料', '豐原', '出口', '13897', '12650', '13260'],
#  ['國1南向', '非主線資料', '豐原', '進口', '13959', '11974', '15650'],
#  ['國1南向', '非主線資料', '大雅', '出口', '30452', '27923', '26500'],
#  ['國1南向', '非主線資料', '大雅', '進口', '12857', '10138', '13913'],
#  ['國1南向', '非主線資料', '台中', '出口', '27462', '24145', '25911'],
#  ['國1南向', '非主線資料', '台中', '進口', '20713', '18698', '17440'],
#  ['國1南向', '非主線資料', '南屯', '出口', '17613', '15525', '16777'],
#  ['國1南向', '非主線資料', '南屯', '進口', '14798', '12599', '13605'],
#  ['國1南向', '非主線資料', '王田', '出口', '10283', '8501', '11330'],
#  ['國1南向', '非主線資料', '王田', '進口', '8908', '7877', '8230'],
#  ['國1南向', '非主線資料', '彰化系統', '出口', '4996', '3965', '4498'],
#  ['國1南向', '非主線資料', '彰化系統', '進口', '32611', '27561', '27361'],
#  ['國1南向', '非主線資料', '彰化', '出口', '24225', '21641', '23310'],
#  ['國1南向', '非主線資料', '彰化', '進口', '16053', '15060', '15670'],
#  ['國1南向', '非主線資料', '埔鹽系統', '出口', '15455', '13591', '14652'],
#  ['國1南向', '非主線資料', '埔鹽系統', '進口1-台76西', '4928', '4399', '4678'],
#  ['國1南向', '非主線資料', '埔鹽系統', '進口2-台76東', '6918', '6554', '5638'],
#  ['國1南向', '非主線資料', '員林', '出口', '13533', '12553', '12437'],
#  ['國1南向', '非主線資料', '員林', '進口', '4936', '4426', '4058'],
#  ['國1南向', '非主線資料', '北斗', '出口', '12366', '11461', '11517'],
#  ['國1南向', '非主線資料', '北斗', '進口', '4726', '4676', '3694'],
#  ['國1南向', '非主線資料', '西螺', '出口', '6715', '5614', '5075'],
#  ['國1南向', '非主線資料', '西螺', '進口', '6541', '6371', '5571'],
#  ['國1南向', '非主線資料', '虎尾', '出口', '5428', '4978', '4232'],
#  ['國1南向', '非主線資料', '虎尾', '進口', '3490', '3534', '2856'],
#  ['國1南向', '非主線資料', '斗南', '出口', '7472', '6082', '5580'],
#  ['國1南向', '非主線資料', '斗南', '進口1-縣158西,斗六', '3091', '2553', '2838'],
#  ['國1南向', '非主線資料', '斗南', '進口2-縣158東,虎尾', '4056', '3555', '3938'],
#  ['國1南向', '非主線資料', '雲林系統', '出口', '12630', '9955', '8544'],
#  ['國1南向', '非主線資料', '雲林系統', '進口', '7682', '6984', '6551'],
#  ['國1南向', '非主線資料', '大林', '出口', '4425', '3651', '3506'],
#  ['國1南向', '非主線資料', '大林', '進口', '4425', '3831', '4552'],
#  ['國1南向', '非主線資料', '民雄', '出口', '8974', '7626', '7385'],
#  ['國1南向', '非主線資料', '民雄', '進口', '5527', '5131', '5045'],
#  ['國1南向', '非主線資料', '嘉義', '出口', '11693', '9849', '9733'],
#  ['國1南向', '非主線資料', '嘉義', '進口', '8444', '8211', '7000'],
#  ['國1南向', '非主線資料', '水上', '出口', '3892', '3554', '3335'],
#  ['國1南向', '非主線資料', '水上', '進口', '2718', '2698', '2353'],
#  ['國1南向', '非主線資料', '嘉義系統', '出口', '7479', '6385', '5966'],
#  ['國1南向', '非主線資料', '嘉義系統', '進口', '6806', '7425', '5428'],
#  ['國1南向', '非主線資料', '新營', '出口', '5659', '4992', '4284'],
#  ['國1南向', '非主線資料', '新營', '進口', '11918', '11463', '11427'],
#  ['國1南向', '非主線資料', '下營系統', '出口', '3975', '4049', '2958'],
#  ['國1南向', '非主線資料', '下營系統', '進口', '8587', '8999', '6873'],
#  ['國1南向', '非主線資料', '麻豆', '出口', '6698', '6559', '5516'],
#  ['國1南向', '非主線資料', '麻豆', '進口', '9007', '8587', '8719'],
#  ['國1南向', '非主線資料', '安定', '出口', '4693', '4921', '5728'],
#  ['國1南向', '非主線資料', '安定', '進口', '5467', '4594', '6614'],
#  ['國1南向', '非主線資料', '台南系統', '出口', '7693', '6798', '6954'],
#  ['國1南向', '非主線資料', '台南系統', '進口', '22244', '21261', '21996'],
#  ['國1南向', '非主線資料', '永康', '出口', '17053', '16759', '13701'],
#  ['國1南向', '非主線資料', '永康', '進口', '16529', '10568', '12912'],
#  ['國1南向', '非主線資料', '大灣', '出口', '16389', '14736', '15517'],
#  ['國1南向', '非主線資料', '台南', '出口', '12212', '11157', '12566'],
#  ['國1南向', '非主線資料', '台南', '進口', '23304', '22182', '20953'],
#  ['國1南向', '非主線資料', '仁德系統', '出口', '15061', '14166', '16007'],
#  ['國1南向', '非主線資料', '仁德系統', '進口', '16018', '14685', '16360'],
#  ['國1南向', '非主線資料', '路竹', '出口', '7901', '7519', '7304'],
#  ['國1南向', '非主線資料', '路竹', '進口', '8595', '7993', '9339'],
#  ['國1南向', '非主線資料', '高科', '出口', '6704', '5688', '9440'],
#  ['國1南向', '非主線資料', '高科', '進口', '7289', '5537', '9603'],
#  ['國1南向', '非主線資料', '岡山', '出口', '7962', '7349', '8737'],
#  ['國1南向', '非主線資料', '岡山', '進口', '17920', '15632', '19750'],
#  ['國1南向', '非主線資料', '楠梓', '出口', '15880', '14915', '17075'],
#  ['國1南向', '非主線資料', '楠梓', '進口', '24822', '20854', '27118'],
#  ['國1南向', '非主線資料', '鼎金系統', '出口', '20854', '18850', '17112'],
#  ['國1南向', '非主線資料', '鼎金系統', '進口', '47109', '46471', '42690'],
#  ['國1南向', '非主線資料', '高雄', '出口1-九如建國', '28761', '28287', '26170'],
#  ['國1南向', '非主線資料', '高雄', '出口2-中正', '20684', '21480', '20202'],
#  ['國1南向', '非主線資料', '高雄', '進口-中正', '15990', '16225', '16102'],
#  ['國1南向', '非主線資料', '瑞隆路', '出口', '15515', '14349', '12782'],
#  ['國1南向', '非主線資料', '五甲系統', '出口', '38561', '35186', '36850'],
#  ['國1南向', '非主線資料', '五甲', '出口-貨櫃車專用', '3072', '2070', '4703'],
#  ['國1南向', '非主線資料', '五甲', '進口', '11191', '10172', '11183'],
#  ['國1南向', '非主線資料', '高雄端', '出口', '38803', '34360', '42141'],
#  ['國1北向', '非主線資料', '基隆端', '出口', '32983', '28503', '28857'],
#  ['國1北向', '非主線資料', '基隆', '出口', '9432', '8400', '9266'],
#  ['國1北向', '非主線資料', '基隆', '進口', '9232', '7718', '9173'],
#  ['國1北向', '非主線資料', '八堵', '出口', '8909', '7950', '7286'],
#  ['國1北向', '非主線資料', '大華系統', '出口', '30563', '28190', '23260'],
#  ['國1北向', '非主線資料', '五堵', '出口', '9396', '8083', '10607'],
#  ['國1北向', '非主線資料', '五堵', '進口1-中油油庫,6.8環道', '175', '190', '220'],
#  ['國1北向', '非主線資料', '五堵', '進口2-5甲', '6826', '5900', '7650'],
#  ['國1北向', '非主線資料', '汐止及汐止系統', '出口1-國3', '26153', '22152', '25160'],
#  ['國1北向', '非主線資料', '汐止及汐止系統', '出口2-汐止', '26852', '23357', '24068'],
#  ['國1北向', '非主線資料', '汐止及汐止系統', '進口1-國3北', '20217', '17953', '15921'],
#  ['國1北向', '非主線資料', '汐止及汐止系統', '進口2-國3南', '5736', '5573', '6038'],
#  ['國1北向', '非主線資料', '汐止及汐止系統', '進口3-汐止', '4678', '4305', '4404'],
#  ['國1北向', '非主線資料', '高架汐止端', '進口', '38328', '34073', '33639'],
#  ['國1北向', '非主線資料', '東湖', '出口', '17104', '15515', '17713'],
#  ['國1北向', '非主線資料', '內湖', '出口', '16994', '15068', '19954'],
#  ['國1北向', '非主線資料', '內湖', '進口1-成功', '9546', '8039', '10265'],
#  ['國1北向', '非主線資料', '內湖', '進口2-南京', '21416', '19244', '20470'],
#  ['國1北向', '非主線資料', '圓山', '出口1-建國', '48552', '43497', '46058'],
#  ['國1北向', '非主線資料', '圓山', '出口2-濱江', '15825', '15074', '15505'],
#  ['國1北向', '非主線資料', '圓山', '進口', '17367', '14984', '17979'],
#  ['國1北向', '非主線資料', '台北', '出口', '24261', '22136', '24481'],
#  ['國1北向', '非主線資料', '台北', '進口', '32383', '29404', '29985'],
#  ['國1北向', '非主線資料', '三重', '出口', '14325', '13891', '13494'],
#  ['國1北向', '非主線資料', '三重', '進口', '24674', '21426', '25700'],
#  ['國1北向', '非主線資料', '五股及五股轉接道', '出口1-台64新五路', '48891', '46693', '49733'],
#  ['國1北向', '非主線資料', '五股及五股轉接道', '出口2-高架', '26249', '22914', '27229'],
#  ['國1北向', '非主線資料', '五股及五股轉接道', '進口', '19721', '16670', '21068'],
#  ['國1北向', '非主線資料', '泰山轉接道', '進口', '33833', '34856', '30669'],
#  ['國1北向', '非主線資料', '林口', '出口1-文化北路', '22575', '21117', '28096'],
#  ['國1北向', '非主線資料', '林口', '出口2-文化一路', '12869', '12889', '16245'],
#  ['國1北向', '非主線資料', '林口', '進口1-文化北路', '17712', '15499', '19857'],
#  ['國1北向', '非主線資料', '林口', '進口2-文化一路', '27450', '24241', '31346'],
#  ['國1北向', '非主線資料', '桃園', '出口', '38012', '35960', '41853'],
#  ['國1北向', '非主線資料', '桃園', '進口1-南崁', '13019', '11902', '14251'],
#  ['國1北向', '非主線資料', '桃園', '進口2-桃園', '25087', '22863', '26581'],
#  ['國1北向', '非主線資料', '機場系統', '出口', '20857', '19021', '23190'],
#  ['國1北向', '非主線資料', '機場系統', '進口', '31444', '28854', '34310'],
#  ['國1北向', '非主線資料', '內壢', '出口1-大園', '4600', '4400', '4800'],
#  ['國1北向', '非主線資料', '內壢', '出口2-中壢', '14590', '13465', '16745'],
#  ['國1北向', '非主線資料', '內壢', '進口', '29909', '26508', '31803'],
#  ['國1北向', '非主線資料', '中壢', '出口', '17302', '15912', '17018'],
#  ['國1北向', '非主線資料', '中壢', '進口', '14562', '12667', '15692'],
#  ['國1北向', '非主線資料', '平鎮系統', '出口', '15760', '14427', '17203'],
#  ['國1北向', '非主線資料', '平鎮系統', '進口', '27710', '25263', '29909'],
#  ['國1北向', '非主線資料', '幼獅', '出口', '4104', '3101', '5502'],
#  ['國1北向', '非主線資料', '幼獅', '進口', '8226', '6638', '11204'],
#  ['國1北向', '非主線資料', '楊梅', '出口', '6051', '5784', '7362'],
#  ['國1北向', '非主線資料', '楊梅', '進口', '24318', '21650', '26963'],
#  ['國1北向', '非主線資料', '高架楊梅端', '出口', '35182', '38376', '29342'],
#  ['國1北向', '非主線資料', '湖口', '出口', '15101', '13809', '20078'],
#  ['國1北向', '非主線資料', '湖口', '進口', '10443', '9901', '12682'],
#  ['國1北向', '非主線資料', '竹北', '出口', '18711', '17031', '24393'],
#  ['國1北向', '非主線資料', '竹北', '進口', '18576', '16013', '18841'],
#  ['國1北向', '非主線資料', '新竹', '出口1-園區二路', '6100', '7034', '10076'],
#  ['國1北向', '非主線資料', '新竹', '出口2-公道五/光復路', '16978', '18247', '16705'],
#  ['國1北向', '非主線資料', '新竹', '進口1-新安路', '8011', '6314', '15862'],
#  ['國1北向', '非主線資料', '新竹', '進口2-光復路', '22725', '19323', '22405'],
#  ['國1北向', '非主線資料', '新竹系統', '出口1-國3北', '16915', '20611', '11006'],
#  ['國1北向', '非主線資料', '新竹系統', '出口2-國3南', '965', '993', '843'],
#  ['國1北向', '非主線資料', '新竹系統', '進口', '27915', '31363', '32404'],
#  ['國1北向', '非主線資料', '頭份', '出口', '7459', '7534', '5958'],
#  ['國1北向', '非主線資料', '頭份', '進口', '16009', '16049', '15828'],
#  ['國1北向', '非主線資料', '頭屋', '出口', '2184', '2451', '1582'],
#  ['國1北向', '非主線資料', '頭屋', '進口', '6565', '7565', '5515'],
#  ['國1北向', '非主線資料', '苗栗', '出口', '7237', '7073', '5782'],
#  ['國1北向', '非主線資料', '苗栗', '進口1-台6西,苗栗', '2750', '3200', '2204'],
#  ['國1北向', '非主線資料', '苗栗', '進口2-台6東,公館', '2072', '3044', '1523'],
#  ['國1北向', '非主線資料', '銅鑼', '出口', '4814', '4369', '4388'],
#  ['國1北向', '非主線資料', '銅鑼', '進口', '2748', '3176', '2315'],
#  ['國1北向', '非主線資料', '三義', '出口', '5271', '5528', '3811'],
#  ['國1北向', '非主線資料', '三義', '進口', '5724', '6478', '5507'],
#  ['國1北向', '非主線資料', '后里', '出口', '12284', '11133', '11969'],
#  ['國1北向', '非主線資料', '后里', '進口', '2920', '3113', '2010'],
#  ['國1北向', '非主線資料', '台中系統', '出口', '29028', '26934', '28089'],
#  ['國1北向', '非主線資料', '台中系統', '進口', '5908', '6476', '5307'],
#  ['國1北向', '非主線資料', '豐原', '出口', '14518', '12550', '16806'],
#  ['國1北向', '非主線資料', '豐原', '進口', '14642', '14597', '14175'],
#  ['國1北向', '非主線資料', '大雅', '出口', '12012', '10614', '13658'],
#  ['國1北向', '非主線資料', '大雅', '進口', '31058', '30245', '27108'],
#  ['國1北向', '非主線資料', '台中', '出口', '18071', '17962', '16426'],
#  ['國1北向', '非主線資料', '台中', '進口', '27874', '25836', '25679'],
#  ['國1北向', '非主線資料', '南屯', '出口', '15566', '15098', '15400'],
#  ['國1北向', '非主線資料', '南屯', '進口', '14647', '13539', '14728'],
#  ['國1北向', '非主線資料', '王田', '出口', '9303', '9171', '9211'],
#  ['國1北向', '非主線資料', '王田', '進口', '10372', '9144', '11981'],
#  ['國1北向', '非主線資料', '彰化系統', '出口', '26635', '30341', '24592'],
#  ['國1北向', '非主線資料', '彰化系統', '進口', '5053', '5321', '5330'],
#  ['國1北向', '非主線資料', '彰化', '出口', '16293', '14416', '15674'],
#  ['國1北向', '非主線資料', '彰化', '進口', '23995', '22994', '23699'],
#  ['國1北向', '非主線資料', '埔鹽系統', '出口', '8445', '7069', '8068'],
#  ['國1北向', '非主線資料', '埔鹽系統', '進口', '14640', '15016', '14882'],
#  ['國1北向', '非主線資料', '員林', '出口', '4247', '4647', '3588'],
#  ['國1北向', '非主線資料', '員林', '進口', '12910', '12566', '12226'],
#  ['國1北向', '非主線資料', '北斗', '出口', '4826', '5576', '3942'],
#  ['國1北向', '非主線資料', '北斗', '進口', '11123', '10689', '10739'],
#  ['國1北向', '非主線資料', '西螺', '出口', '6054', '6440', '5285'],
#  ['國1北向', '非主線資料', '西螺', '進口', '6379', '6854', '5509'],
#  ['國1北向', '非主線資料', '虎尾', '出口', '3606', '3921', '3050'],
#  ['國1北向', '非主線資料', '虎尾', '進口', '4321', '4692', '3811'],
#  ['國1北向', '非主線資料', '斗南', '出口', '6757', '5996', '6560'],
#  ['國1北向', '非主線資料', '斗南', '進口1-縣158東,虎尾', '4430', '4357', '3908'],
#  ['國1北向', '非主線資料', '斗南', '進口2-縣158西,斗六', '2579', '2724', '1849'],
#  ['國1北向', '非主線資料', '雲林系統', '出口', '7222', '7203', '6246'],
#  ['國1北向', '非主線資料', '雲林系統', '進口', '11415', '11758', '8591'],
#  ['國1北向', '非主線資料', '大林', '出口', '4627', '4199', '4892'],
#  ['國1北向', '非主線資料', '大林', '進口', '3798', '4115', '3339'],
#  ['國1北向', '非主線資料', '民雄', '出口', '5649', '5327', '5155'],
#  ['國1北向', '非主線資料', '民雄', '進口', '8159', '8338', '7152'],
#  ['國1北向', '非主線資料', '嘉義', '出口', '8909', '8290', '7252'],
#  ['國1北向', '非主線資料', '嘉義', '進口', '11164', '11193', '9776'],
#  ['國1北向', '非主線資料', '水上', '出口', '2475', '2510', '2193'],
#  ['國1北向', '非主線資料', '水上', '進口', '3512', '3710', '3318'],
#  ['國1北向', '非主線資料', '嘉義系統', '出口', '6939', '7165', '5232'],
#  ['國1北向', '非主線資料', '嘉義系統', '進口', '6980', '7671', '6202'],
#  ['國1北向', '非主線資料', '新營', '出口', '12117', '11074', '11465'],
#  ['國1北向', '非主線資料', '新營', '進口', '5126', '5527', '4187'],
#  ['國1北向', '非主線資料', '下營系統', '出口', '8194', '8679', '6730'],
#  ['國1北向', '非主線資料', '下營系統', '進口', '3536', '4024', '2861'],
#  ['國1北向', '非主線資料', '麻豆', '出口', '5311', '4989', '7132'],
#  ['國1北向', '非主線資料', '麻豆', '進口', '6179', '6591', '5326'],
#  ['國1北向', '非主線資料', '安定', '出口', '5311', '4989', '7132'],
#  ['國1北向', '非主線資料', '安定', '進口', '4805', '4387', '5735'],
#  ['國1北向', '非主線資料', '台南系統', '出口', '16006', '15272', '18464'],
#  ['國1北向', '非主線資料', '台南系統', '進口', '6870', '6726', '6324'],
#  ['國1北向', '非主線資料', '永康', '出口', '15119', '14316', '17155'],
#  ['國1北向', '非主線資料', '永康', '進口', '16809', '16648', '14863'],
#  ['國1北向', '非主線資料', '大灣', '進口', '15074', '14401', '13752'],
#  ['國1北向', '非主線資料', '台南', '出口', '22586', '23122', '21627'],
#  ['國1北向', '非主線資料', '台南', '進口', '12161', '11796', '11847'],
#  ['國1北向', '非主線資料', '仁德系統', '出口', '15921', '15167', '15646'],
#  ['國1北向', '非主線資料', '仁德系統', '進口', '14337', '14592', '15980'],
#  ['國1北向', '非主線資料', '路竹', '出口', '7918', '7833', '8815'],
#  ['國1北向', '非主線資料', '路竹', '進口', '7621', '7490', '7159'],
#  ['國1北向', '非主線資料', '高科', '出口', '6711', '5688', '9196'],
#  ['國1北向', '非主線資料', '高科', '進口', '6739', '6024', '9288'],
#  ['國1北向', '非主線資料', '岡山', '出口', '16287', '14512', '18397'],
#  ['國1北向', '非主線資料', '岡山', '進口', '7627', '7567', '7912'],
#  ['國1北向', '非主線資料', '楠梓', '出口', '21814', '19429', '24525'],
#  ['國1北向', '非主線資料', '楠梓', '進口', '16469', '15455', '17851'],
#  ['國1北向', '非主線資料', '鼎金系統', '出口', '47171', '44264', '45800'],
#  ['國1北向', '非主線資料', '鼎金系統', '進口', '23450', '22096', '21797'],
#  ['國1北向', '非主線資料', '高雄', '出口1-中正', '6550', '6160', '6325'],
#  ['國1北向', '非主線資料', '高雄', '出口2-三多', '9809', '9315', '8485'],
#  ['國1北向', '非主線資料', '高雄', '進口1-九如建國', '24930', '24567', '20105'],
#  ['國1北向', '非主線資料', '高雄', '進口2-中正', '23043', '24639', '24380'],
#  ['國1北向', '非主線資料', '五甲系統暨南華路進口', '進口', '50842', '51090', '46868'],
#  ['國1北向', '非主線資料', '五甲', '出口', '9532', '8421', '9687'],
#  ['國1北向', '非主線資料', '五甲', '進口-貨櫃車專用', '2249', '2253', '2336'],
#  ['國1北向', '非主線資料', '高雄端', '進口', '29000', '27000', '31000'],
#  ['國3南向', '非主線資料', '基港端', '進口1-聯外道路', '1000', '1,008', '1,130'],
#  ['國3南向', '非主線資料', '基港端', '進口2-光華路', '1022', '1,024', '1,146'],
#  ['國3南向', '非主線資料', '基港端', '進口3-德安路', '2027', '2,025', '2,639'],
#  ['國3南向', '非主線資料', '基港端', '進口4-中和路', '4799', '4,825', '4,715'],
#  ['國3南向', '非主線資料', '基金', '進口', '11559', '11747', '11622'],
#  ['國3南向', '非主線資料', '瑪東系統', '出口', '3453', '2929', '3622'],
#  ['國3南向', '非主線資料', '瑪東系統', '進口', '2744', '3765', '3395'],
#  ['國3南向', '非主線資料', '汐止系統', '出口', '10553', '11370', '11347'],
#  ['國3南向', '非主線資料', '汐止系統', '進口', '35420', '31557', '33821'],
#  ['國3南向', '非主線資料', '新台五路', '出口', '10440', '9136', '14101'],
#  ['國3南向', '非主線資料', '新台五路', '進口1-新台五路西', '7562', '6937', '10914'],
#  ['國3南向', '非主線資料', '新台五路', '進口2-新台五路東', '8269', '6903', '7765'],
#  ['國3南向', '非主線資料', '南港', '進口', '16348', '14484', '17854'],
#  ['國3南向', '非主線資料', '南港系統', '出口', '21722', '18572', '15746'],
#  ['國3南向', '非主線資料', '南港系統', '進口', '16627', '19232', '11649'],
#  ['國3南向', '非主線資料', '木柵', '出口', '19485', '18058', '20164'],
#  ['國3南向', '非主線資料', '木柵', '進口', '16244', '15195', '15635'],
#  ['國3南向', '非主線資料', '新店', '出口', '13975', '12878', '15714'],
#  ['國3南向', '非主線資料', '新店', '進口', '12090', '10620', '13130'],
#  ['國3南向', '非主線資料', '安坑', '出口', '10781', '10057', '11826'],
#  ['國3南向', '非主線資料', '安坑', '進口', '31670', '27698', '31103'],
#  ['國3南向', '非主線資料', '中和', '出口', '23890', '22540', '25153'],
#  ['國3南向', '非主線資料', '中和', '進口', '37861', '34145', '35742'],
#  ['國3南向', '非主線資料', '土城', '出口', '17669', '15162', '21515'],
#  ['國3南向', '非主線資料', '土城', '進口', '38774', '34630', '35661'],
#  ['國3南向', '非主線資料', '樹林', '出口', '18333', '13256', '15892'],
#  ['國3南向', '非主線資料', '三鶯', '出口-1鶯歌', '6667', '6259', '6920'],
#  ['國3南向', '非主線資料', '三鶯', '出口2-三峽', '8349', '8483', '7586'],
#  ['國3南向', '非主線資料', '三鶯', '進口', '19080', '18195', '18885'],
#  ['國3南向', '非主線資料', '鶯歌系統', '出口', '30147', '29532', '32125'],
#  ['國3南向', '非主線資料', '鶯歌系統', '進口', '18153', '16137', '17671'],
#  ['國3南向', '非主線資料', '大溪', '出口', '25741', '25843', '27143'],
#  ['國3南向', '非主線資料', '大溪', '進口1-永昌路', '4339', '4030', '3441'],
#  ['國3南向', '非主線資料', '大溪', '進口2-觀音', '6361', '5072', '4806'],
#  ['國3南向', '非主線資料', '龍潭', '出口', '15576', '15410', '16735'],
#  ['國3南向', '非主線資料', '龍潭', '進口', '6471', '5595', '5178'],
#  ['國3南向', '非主線資料', '關西', '出口', '7281', '6293', '4229'],
#  ['國3南向', '非主線資料', '關西', '進口', '5931', '5384', '4997'],
#  ['國3南向', '非主線資料', '竹林', '出口', '15879', '14578', '12013'],
#  ['國3南向', '非主線資料', '竹林', '進口', '6833', '6274', '6900'],
#  ['國3南向', '非主線資料', '寶山', '出口', '4397', '4262', '6088'],
#  ['國3南向', '非主線資料', '寶山', '進口', '5712', '4624', '7958'],
#  ['國3南向', '非主線資料', '新竹系統', '出口', '21071', '17644', '15218'],
#  ['國3南向', '非主線資料', '新竹系統', '進口', '31485', '24576', '29200'],
#  ['國3南向', '非主線資料', '茄苳', '出口', '10977', '10480', '12298'],
#  ['國3南向', '非主線資料', '茄苳', '進口', '7366', '5839', '6142'],
#  ['國3南向', '非主線資料', '香山', '出口', '8702', '7277', '12930'],
#  ['國3南向', '非主線資料', '香山', '進口', '4787', '3473', '4507'],
#  ['國3南向', '非主線資料', '西濱', '出口', '7882', '6524', '7906'],
#  ['國3南向', '非主線資料', '竹南', '出口', '4863', '3902', '4073'],
#  ['國3南向', '非主線資料', '竹南', '進口', '5102', '4289', '3910'],
#  ['國3南向', '非主線資料', '大山', '出口', '3366', '2676', '2809'],
#  ['國3南向', '非主線資料', '大山', '進口', '2655', '1927', '1882'],
#  ['國3南向', '非主線資料', '後龍', '出口', '5211', '4065', '3864'],
#  ['國3南向', '非主線資料', '後龍', '進口', '4102', '4301', '3604'],
#  ['國3南向', '非主線資料', '通霄', '出口', '6155', '4744', '4867'],
#  ['國3南向', '非主線資料', '通霄', '進口', '3796', '3723', '2324'],
#  ['國3南向', '非主線資料', '苑裡', '出口', '4729', '3840', '2783'],
#  ['國3南向', '非主線資料', '苑裡', '進口', '8382', '8152', '8566'],
#  ['國3南向', '非主線資料', '大甲', '出口', '4548', '3914', '3401'],
#  ['國3南向', '非主線資料', '大甲', '進口', '12004', '11566', '11225'],
#  ['國3南向', '非主線資料', '中港系統', '出口', '16295', '15125', '14705'],
#  ['國3南向', '非主線資料', '中港系統', '進口', '5928', '5477', '5430'],
#  ['國3南向', '非主線資料', '沙鹿', '出口', '9935', '9248', '9293'],
#  ['國3南向', '非主線資料', '沙鹿', '進口', '13387', '11087', '11823'],
#  ['國3南向', '非主線資料', '龍井', '出口', '13340', '11412', '11839'],
#  ['國3南向', '非主線資料', '龍井', '進口', '11340', '9393', '10881'],
#  ['國3南向', '非主線資料', '和美', '出口', '6703', '5568', '6284'],
#  ['國3南向', '非主線資料', '和美', '進口', '12872', '12025', '14539'],
#  ['國3南向', '非主線資料', '彰化系統', '出口', '24115', '19507', '19191'],
#  ['國3南向', '非主線資料', '彰化系統', '進口', '12769', '10809', '11976'],
#  ['國3南向', '非主線資料', '快官', '出口', '14059', '12733', '13364'],
#  ['國3南向', '非主線資料', '快官', '進口', '24465', '22636', '23376'],
#  ['國3南向', '非主線資料', '烏日', '出口', '4582', '3411', '6658'],
#  ['國3南向', '非主線資料', '烏日', '進口', '6610', '4929', '7006'],
#  ['國3南向', '非主線資料', '中投', '出口', '8768', '7418', '9307'],
#  ['國3南向', '非主線資料', '中投', '進口', '12180', '10536', '10105'],
#  ['國3南向', '非主線資料', '霧峰', '出口', '14278', '13165', '15317'],
#  ['國3南向', '非主線資料', '霧峰', '進口', '42701', '40437', '31260'],
#  ['國3南向', '非主線資料', '霧峰系統', '出口', '19534', '16829', '11820'],
#  ['國3南向', '非主線資料', '霧峰系統', '進口', '5214', '6976', '3677'],
#  ['國3南向', '非主線資料', '草屯', '出口', '6433', '6105', '6398'],
#  ['國3南向', '非主線資料', '草屯', '進口', '3740', '3138', '2941'],
#  ['國3南向', '非主線資料', '中興系統', '出口', '12453', '11995', '9779'],
#  ['國3南向', '非主線資料', '中興系統', '進口', '6003', '6060', '4629'],
#  ['國3南向', '非主線資料', '中興', '出口', '9934', '9106', '10796'],
#  ['國3南向', '非主線資料', '中興', '進口', '6158', '5451', '5399'],
#  ['國3南向', '非主線資料', '南投', '出口', '11171', '9929', '10940'],
#  ['國3南向', '非主線資料', '南投', '進口', '3223', '2941', '2836'],
#  ['國3南向', '非主線資料', '名間', '出口', '10424', '9339', '7444'],
#  ['國3南向', '非主線資料', '名間', '進口', '3168', '3063', '2476'],
#  ['國3南向', '非主線資料', '竹山', '出口', '12177', '11359', '7851'],
#  ['國3南向', '非主線資料', '竹山', '進口', '4346', '5552', '2715'],
#  ['國3南向', '非主線資料', '南雲', '出口', '2691', '2258', '1789'],
#  ['國3南向', '非主線資料', '南雲', '進口', '2531', '2727', '1835'],
#  ['國3南向', '非主線資料', '斗六', '出口', '5777', '4979', '4171'],
#  ['國3南向', '非主線資料', '斗六', '進口', '4438', '4510', '4020'],
#  ['國3南向', '非主線資料', '古坑系統', '出口', '6257', '5874', '4071'],
#  ['國3南向', '非主線資料', '古坑系統', '進口', '3033', '3012', '1992'],
#  ['國3南向', '非主線資料', '古坑', '出口', '602', '563', '314'],
#  ['國3南向', '非主線資料', '古坑', '進口', '1520', '1606', '1002'],
#  ['國3南向', '非主線資料', '梅山', '出口', '3039', '2908', '2268'],
#  ['國3南向', '非主線資料', '梅山', '進口', '5758', '5887', '4710'],
#  ['國3南向', '非主線資料', '竹崎', '出口', '8011', '7374', '5725'],
#  ['國3南向', '非主線資料', '竹崎', '進口', '6225', '6378', '5420'],
#  ['國3南向', '非主線資料', '中埔', '出口', '7064', '6449', '4847'],
#  ['國3南向', '非主線資料', '中埔', '進口', '7497', '9227', '5322'],
#  ['國3南向', '非主線資料', '水上系統', '出口', '7247', '7048', '5420'],
#  ['國3南向', '非主線資料', '水上系統', '進口', '2940', '3171', '1749'],
#  ['國3南向', '非主線資料', '白河', '出口', '3743', '3764', '2450'],
#  ['國3南向', '非主線資料', '白河', '進口', '3215', '4200', '2073'],
#  ['國3南向', '非主線資料', '柳營', '出口', '1414', '1570', '967'],
#  ['國3南向', '非主線資料', '柳營', '進口', '2839', '2938', '2575'],
#  ['國3南向', '非主線資料', '烏山頭', '出口', '1432', '1493', '978'],
#  ['國3南向', '非主線資料', '烏山頭', '進口', '3606', '3972', '3019'],
#  ['國3南向', '非主線資料', '官田系統', '出口', '3324', '3571', '2111'],
#  ['國3南向', '非主線資料', '官田系統', '進口', '5627', '6420', '4361'],
#  ['國3南向', '非主線資料', '善化', '出口', '3637', '4202', '3287'],
#  ['國3南向', '非主線資料', '善化', '進口', '3846', '3413', '3380'],
#  ['國3南向', '非主線資料', '新化系統', '出口', '11147', '13667', '7177'],
#  ['國3南向', '非主線資料', '新化系統', '進口', '8966', '8289', '7634'],
#  ['國3南向', '非主線資料', '關廟', '出口', '7099', '7744', '6311'],
#  ['國3南向', '非主線資料', '關廟', '進口', '5286', '5427', '3559'],
#  ['國3南向', '非主線資料', '田寮', '出口', '3632', '4090', '2674'],
#  ['國3南向', '非主線資料', '田寮', '進口', '2811', '2854', '2263'],
#  ['國3南向', '非主線資料', '燕巢系統', '出口', '10134', '11066', '9356'],
#  ['國3南向', '非主線資料', '燕巢系統', '進口1-國10東', '11578', '10512', '10627'],
#  ['國3南向', '非主線資料', '燕巢系統', '進口2-國10西', '1389', '1512', '1227'],
#  ['國3南向', '非主線資料', '九如', '出口', '11214', '10760', '9741'],
#  ['國3南向', '非主線資料', '九如', '進口', '2644', '2507', '2322'],
#  ['國3南向', '非主線資料', '長治', '出口', '6015', '5710', '4748'],
#  ['國3南向', '非主線資料', '長治', '進口', '4264', '4047', '3957'],
#  ['國3南向', '非主線資料', '麟洛', '出口', '4432', '4116', '3952'],
#  ['國3南向', '非主線資料', '麟洛', '進口', '7573', '6986', '6873'],
#  ['國3南向', '非主線資料', '竹田系統', '出口', '7551', '7119', '6864'],
#  ['國3南向', '非主線資料', '竹田系統', '進口', '15757', '14186', '10882'],
#  ['國3南向', '非主線資料', '崁頂', '出口', '4169', '3680', '3617'],
#  ['國3南向', '非主線資料', '南州', '出口', '16398', '14391', '10717'],
#  ['國3南向', '非主線資料', '南州', '進口', '809', '574', '502'],
#  ['國3南向', '非主線資料', '林邊', '出口', '6831', '5738', '3954'],
#  ['國3南向', '非主線資料', '大鵬灣端', '出口', '1201', '1342', '817'],
#  ['國3北向', '非主線資料', '基港端', '出口1-中和路', '5125', '5109', '5132'],
#  ['國3北向', '非主線資料', '基港端', '出口2-德安路', '2304', '2320', '2297'],
#  ['國3北向', '非主線資料', '基港端', '出口3-中山四路', '1287', '1046', '813'],
#  ['國3北向', '非主線資料', '基港端', '出口4-中山三路', '1339', '1330', '809'],
#  ['國3北向', '非主線資料', '基港端', '出口5-聯外道路', '1279', '1046', '819'],
#  ['國3北向', '非主線資料', '基金', '出口', '11380', '10199', '11405'],
#  ['國3北向', '非主線資料', '瑪東系統', '出口', '2743', '2330', '2326'],
#  ['國3北向', '非主線資料', '瑪東系統', '進口', '2711', '2315', '3058'],
#  ['國3北向', '非主線資料', '汐止系統', '出口', '35217', '33435', '33322'],
#  ['國3北向', '非主線資料', '汐止系統', '進口', '18151', '16576', '15709'],
#  ['國3北向', '非主線資料', '新台五路', '出口', '15760', '14857', '19469'],
#  ['國3北向', '非主線資料', '新台五路', '進口', '9143', '8117', '12113'],
#  ['國3北向', '非主線資料', '南港', '出口', '15903', '15741', '18800'],
#  ['國3北向', '非主線資料', '南港系統', '出口', '15358', '12410', '9113'],
#  ['國3北向', '非主線資料', '南港系統', '進口', '18677', '20727', '15131'],
#  ['國3北向', '非主線資料', '南深路', '出口', '3441', '2752', '3043'],
#  ['國3北向', '非主線資料', '木柵', '出口', '16341', '14987', '16040'],
#  ['國3北向', '非主線資料', '木柵', '進口', '16155', '14183', '16954'],
#  ['國3北向', '非主線資料', '新店', '出口', '9655', '9053', '11153'],
#  ['國3北向', '非主線資料', '新店', '進口', '10556', '9320', '12020'],
#  ['國3北向', '非主線資料', '安坑', '出口', '28006', '26452', '28543'],
#  ['國3北向', '非主線資料', '安坑', '進口1-中央路/環河路', '4226', '3501', '4072'],
#  ['國3北向', '非主線資料', '安坑', '進口2-安康路', '7226', '6228', '8526'],
#  ['國3北向', '非主線資料', '中和', '出口', '36201', '35945', '33863'],
#  ['國3北向', '非主線資料', '中和', '進口', '23005', '20564', '23204'],
#  ['國3北向', '非主線資料', '土城', '出口', '40833', '41464', '39604'],
#  ['國3北向', '非主線資料', '土城', '進口', '17619', '14541', '20142'],
#  ['國3北向', '非主線資料', '樹林', '進口', '18980', '18425', '18392'],
#  ['國3北向', '非主線資料', '三鶯', '出口', '19452', '19621', '19618'],
#  ['國3北向', '非主線資料', '三鶯', '進口', '14918', '14216', '14792'],
#  ['國3北向', '非主線資料', '鶯歌系統', '出口', '20216', '21732', '20710'],
#  ['國3北向', '非主線資料', '鶯歌系統', '進口', '39382', '35019', '41119'],
#  ['國3北向', '非主線資料', '大溪', '出口', '9189', '10646', '7874'],
#  ['國3北向', '非主線資料', '大溪', '進口', '24188', '22083', '25183'],
#  ['國3北向', '非主線資料', '龍潭', '出口', '5883', '8073', '5451'],
#  ['國3北向', '非主線資料', '龍潭', '進口', '15861', '15190', '16497'],
#  ['國3北向', '非主線資料', '關西', '出口', '7119', '6897', '5702'],
#  ['國3北向', '非主線資料', '關西', '進口', '6517', '7855', '4811'],
#  ['國3北向', '非主線資料', '竹林', '出口', '6693', '6547', '6309'],
#  ['國3北向', '非主線資料', '竹林', '進口', '16104', '15944', '12287'],
#  ['國3北向', '非主線資料', '寶山', '出口', '5017', '5637', '7061'],
#  ['國3北向', '非主線資料', '寶山', '進口', '4188', '4126', '5336'],
#  ['國3北向', '非主線資料', '新竹系統', '出口', '25903', '29397', '28703'],
#  ['國3北向', '非主線資料', '新竹系統', '進口', '19453', '22391', '14711'],
#  ['國3北向', '非主線資料', '茄苳', '出口', '5776', '6529', '5566'],
#  ['國3北向', '非主線資料', '茄苳', '進口', '10294', '9387', '11015'],
#  ['國3北向', '非主線資料', '香山', '出口', '3740', '4420', '4436'],
#  ['國3北向', '非主線資料', '香山', '進口', '8063', '7349', '12542'],
#  ['國3北向', '非主線資料', '西濱', '進口', '7014', '7074', '7379'],
#  ['國3北向', '非主線資料', '竹南', '出口', '5001', '5912', '4461'],
#  ['國3北向', '非主線資料', '竹南', '進口', '4373', '4715', '4510'],
#  ['國3北向', '非主線資料', '大山', '出口', '955', '1120', '995'],
#  ['國3北向', '非主線資料', '大山', '進口', '2394', '2734', '2459'],
#  ['國3北向', '非主線資料', '後龍', '出口', '4214', '4909', '3842'],
#  ['國3北向', '非主線資料', '後龍', '進口', '3278', '3895', '3155'],
#  ['國3北向', '非主線資料', '通霄', '出口', '3747', '4567', '3216'],
#  ['國3北向', '非主線資料', '通霄', '進口', '5097', '6156', '4628'],
#  ['國3北向', '非主線資料', '苑裡', '出口', '8038', '7731', '8103'],
#  ['國3北向', '非主線資料', '苑裡', '進口', '3454', '4152', '3087'],
#  ['國3北向', '非主線資料', '大甲', '出口', '12242', '12160', '11643'],
#  ['國3北向', '非主線資料', '大甲', '進口', '3680', '4247', '3200'],
#  ['國3北向', '非主線資料', '中港系統', '出口', '6509', '6249', '6309'],
#  ['國3北向', '非主線資料', '中港系統', '進口', '15132', '16052', '14428'],
#  ['國3北向', '非主線資料', '沙鹿', '出口', '9742', '9607', '9800'],
#  ['國3北向', '非主線資料', '沙鹿', '進口', '8759', '8997', '8486'],
#  ['國3北向', '非主線資料', '龍井', '出口', '9822', '10334', '10546'],
#  ['國3北向', '非主線資料', '龍井', '進口', '10291', '10193', '10041'],
#  ['國3北向', '非主線資料', '和美', '出口', '13587', '12558', '15091'],
#  ['國3北向', '非主線資料', '和美', '進口', '5646', '6549', '6096'],
#  ['國3北向', '非主線資料', '彰化系統', '出口', '12282', '12143', '11658'],
#  ['國3北向', '非主線資料', '彰化系統', '進口', '18331', '22776', '16408'],
#  ['國3北向', '非主線資料', '快官', '出口', '23635', '24700', '23551'],
#  ['國3北向', '非主線資料', '快官', '進口', '14221', '14325', '14278'],
#  ['國3北向', '非主線資料', '烏日', '出口', '5923', '5653', '7010'],
#  ['國3北向', '非主線資料', '烏日', '進口', '4765', '3925', '6857'],
#  ['國3北向', '非主線資料', '中投', '出口', '13313', '13069', '12283'],
#  ['國3北向', '非主線資料', '中投', '進口', '8393', '7959', '8985'],
#  ['國3北向', '非主線資料', '霧峰', '出口', '31916', '36590', '26495'],
#  ['國3北向', '非主線資料', '霧峰', '進口', '14012', '13387', '15230'],
#  ['國3北向', '非主線資料', '霧峰系統', '出口', '9272', '10551', '5892'],
#  ['國3北向', '非主線資料', '霧峰系統', '進口', '19776', '21548', '15570'],
#  ['國3北向', '非主線資料', '草屯', '出口1-台14線,草屯', '3355', '4747', '3157'],
#  ['國3北向', '非主線資料', '草屯', '出口2-台15線,芬園', '1280', '1478', '1194'],
#  ['國3北向', '非主線資料', '草屯', '進口', '8634', '10420', '8060'],
#  ['國3北向', '非主線資料', '中興系統', '出口', '5842', '6731', '5027'],
#  ['國3北向', '非主線資料', '中興系統', '進口', '11691', '13599', '9830'],
#  ['國3北向', '非主線資料', '中興', '出口', '5956', '6149', '5503'],
#  ['國3北向', '非主線資料', '中興', '進口', '10932', '10554', '12169'],
#  ['國3北向', '非主線資料', '南投', '出口', '3498', '3794', '3192'],
#  ['國3北向', '非主線資料', '南投', '進口', '10880', '10319', '11022'],
#  ['國3北向', '非主線資料', '名間', '出口', '2867', '3371', '2477'],
#  ['國3北向', '非主線資料', '名間', '進口', '9192', '10877', '7566'],
#  ['國3北向', '非主線資料', '竹山', '出口', '5151', '5075', '2906'],
#  ['國3北向', '非主線資料', '竹山', '進口', '10031', '12625', '7661'],
#  ['國3北向', '非主線資料', '南雲', '出口', '2631', '2706', '1812'],
#  ['國3北向', '非主線資料', '南雲', '進口', '2658', '3068', '2267'],
#  ['國3北向', '非主線資料', '斗六', '出口', '4181', '4475', '3651'],
#  ['國3北向', '非主線資料', '斗六', '進口', '5224', '5782', '4174'],
#  ['國3北向', '非主線資料', '古坑系統', '出口', '2839', '3072', '1975'],
#  ['國3北向', '非主線資料', '古坑系統', '進口', '5476', '7124', '3829'],
#  ['國3北向', '非主線資料', '古坑', '出口', '1599', '1809', '1079'],
#  ['國3北向', '非主線資料', '古坑', '進口', '446', '582', '264'],
#  ['國3北向', '非主線資料', '梅山', '出口', '5675', '5737', '4616'],
#  ['國3北向', '非主線資料', '梅山', '進口', '2692', '3268', '2160'],
#  ['國3北向', '非主線資料', '竹崎', '出口', '6229', '6208', '5338'],
#  ['國3北向', '非主線資料', '竹崎', '進口', '7186', '8269', '5637'],
#  ['國3北向', '非主線資料', '中埔', '出口', '7876', '8249', '4883'],
#  ['國3北向', '非主線資料', '中埔', '進口', '6022', '7169', '4779'],
#  ['國3北向', '非主線資料', '水上系統', '出口', '2702', '3091', '1724'],
#  ['國3北向', '非主線資料', '水上系統', '進口', '5332', '6091', '4505'],
#  ['國3北向', '非主線資料', '白河', '出口', '3389', '3960', '1982'],
#  ['國3北向', '非主線資料', '白河', '進口', '3097', '3915', '2075'],
#  ['國3北向', '非主線資料', '柳營', '出口', '2937', '3025', '2659'],
#  ['國3北向', '非主線資料', '柳營', '進口', '1560', '1889', '1072'],
#  ['國3北向', '非主線資料', '烏山頭', '出口', '3752', '4063', '3083'],
#  ['國3北向', '非主線資料', '烏山頭', '進口', '1489', '1744', '1030'],
#  ['國3北向', '非主線資料', '官田系統', '出口', '5649', '5950', '4061'],
#  ['國3北向', '非主線資料', '官田系統', '進口', '3279', '4310', '2260'],
#  ['國3北向', '非主線資料', '善化', '出口', '3725', '3587', '3515'],
#  ['國3北向', '非主線資料', '善化', '進口', '3787', '3850', '3163'],
#  ['國3北向', '非主線資料', '新化系統', '出口', '7042', '7327', '7334'],
#  ['國3北向', '非主線資料', '新化系統', '進口', '11868', '12777', '7389'],
#  ['國3北向', '非主線資料', '關廟', '出口', '6412', '8555', '4883'],
#  ['國3北向', '非主線資料', '關廟', '進口', '9264', '10217', '7476'],
#  ['國3北向', '非主線資料', '田寮', '出口', '2323', '2387', '2097'],
#  ['國3北向', '非主線資料', '田寮', '進口', '3073', '4332', '1900'],
#  ['國3北向', '非主線資料', '燕巢系統', '出口', '13334', '15449', '12630'],
#  ['國3北向', '非主線資料', '燕巢系統', '進口1-國10西', '3119', '3021', '2451'],
#  ['國3北向', '非主線資料', '燕巢系統', '進口2-國10東', '9356', '9803', '6067'],
#  ['國3北向', '非主線資料', '九如', '出口', '2774', '2870', '2452'],
#  ['國3北向', '非主線資料', '九如', '進口', '10224', '10985', '9575'],
#  ['國3北向', '非主線資料', '長治', '出口', '4182', '3968', '3907'],
#  ['國3北向', '非主線資料', '長治', '進口', '5566', '6277', '4904'],
#  ['國3北向', '非主線資料', '麟洛', '出口', '7245', '7050', '6733'],
#  ['國3北向', '非主線資料', '麟洛', '進口', '4363', '4618', '4137'],
#  ['國3北向', '非主線資料', '竹田系統', '出口', '11807', '15302', '9901'],
#  ['國3北向', '非主線資料', '竹田系統', '進口', '7383', '7325', '6865'],
#  ['國3北向', '非主線資料', '崁頂', '進口', '4138', '4494', '4031'],
#  ['國3北向', '非主線資料', '南州', '出口', '618', '600', '516'],
#  ['國3北向', '非主線資料', '南州', '進口', '12841', '17161', '10763'],
#  ['國3北向', '非主線資料', '林邊', '進口', '5024', '6355', '3875'],
#  ['國3北向', '非主線資料', '大鵬灣端', '進口', '1270', '1517', '858'],
#  ['國1高架南向', '非主線資料', '汐止端', '進口', '32505', '34285', '30356'],
#  ['國1高架南向', '非主線資料', '堤頂', '出口', '11853', '11492', '13268'],
#  ['國1高架南向', '非主線資料', '堤頂', '進口', '22697', '19622', '26919'],
#  ['國1高架南向', '非主線資料', '環北', '進口', '26137', '24394', '24672'],
#  ['國1高架南向', '非主線資料', '五股轉接道', '出口1-新五路台64', '25808', '21269', '20754'],
#  ['國1高架南向', '非主線資料', '五股轉接道', '出口2-國1平面', '21245', '24916', '29071'],
#  ['國1高架南向', '非主線資料', '泰山轉接道', '進口', '40073', '36826', '33182'],
#  ['國1高架南向', '非主線資料', '機場系統', '出口', '21326', '22036', '21960'],
#  ['國1高架南向', '非主線資料', '機場系統', '進口', '7882', '7366', '8238'],
#  ['國1高架南向', '非主線資料', '中壢轉接道', '出口', '19,726', '15,262', '15,264'],
#  ['國1高架南向', '非主線資料', '中壢轉接道', '進口', '17,193', '12,448', '12,450'],
#  ['國1高架南向', '非主線資料', '楊梅端', '出口', '41286', '36050', '32419'],
#  ['國2東向', '非主線資料', '機場端', '進口', '44245', '46200', '46532'],
#  ['國2東向', '非主線資料', '大園', '出口', '5500', '4350', '4300'],
#  ['國2東向', '非主線資料', '大園', '進口', '18397', '17178', '23024'],
#  ['國2東向', '非主線資料', '大竹', '出口', '5697', '5525', '6964'],
#  ['國2東向', '非主線資料', '大竹', '進口', '22163', '19983', '25512'],
#  ['國2東向', '非主線資料', '機場系統', '出口', '46079', '45695', '50868'],
#  ['國2東向', '非主線資料', '機場系統', '進口', '43100', '40552', '44778'],
#  ['國2東向', '非主線資料', '南桃園', '出口', '32520', '31437', '35716'],
#  ['國2東向', '非主線資料', '南桃園', '進口', '19500', '18800', '19581'],
#  ['國2東向', '非主線資料', '大湳', '出口', '20503', '18691', '23601'],
#  ['國2東向', '非主線資料', '大湳', '進口', '22800', '23800', '23315'],
#  ['國2東向', '非主線資料', '鶯歌系統', '出口', '58948', '50719', '59068'],
#  ['國1高架北向', '非主線資料', '汐止端', '出口', '38328', '34073', '33639'],
#  ['國1高架北向', '非主線資料', '堤頂', '出口', '18647', '17375', '22670'],
#  ['國1高架北向', '非主線資料', '堤頂', '進口', '12916', '11214', '14188'],
#  ['國1高架北向', '非主線資料', '下塔悠', '出口', '6874', '6562', '9757'],
#  ['國1高架北向', '非主線資料', '環北', '出口', '28416', '27623', '27872'],
#  ['國1高架北向', '非主線資料', '五股轉接道', '進口1-新五路台64', '28897', '23893', '30669'],
#  ['國1高架北向', '非主線資料', '五股轉接道', '進口2-國1平面', '23812', '23538', '23887'],
#  ['國1高架北向', '非主線資料', '泰山轉接道', '出口', '33833', '34856', '30669'],
#  ['國1高架北向', '非主線資料', '機場系統', '出口', '8143', '8049', '8463'],
#  ['國1高架北向', '非主線資料', '機場系統', '進口', '20646', '20564', '21402'],
#  ['國1高架北向', '非主線資料', '中壢轉接道', '出口', '15987', '22158', '16214'],
#  ['國1高架北向', '非主線資料', '中壢轉接道', '進口', '20367', '25390', '19884'],
#  ['國1高架北向', '非主線資料', '楊梅端', '進口', '37182', '39376', '32342'],
#  ['國2西向', '非主線資料', '機場端', '出口', '43294', '43626', '46599'],
#  ['國2西向', '非主線資料', '大園', '出口', '18832', '16580', '22032'],
#  ['國2西向', '非主線資料', '大園', '進口', '6722', '6642', '7225'],
#  ['國2西向', '非主線資料', '大竹', '出口', '23695', '20858', '25258'],
#  ['國2西向', '非主線資料', '大竹', '進口', '4839', '4431', '5765'],
#  ['國2西向', '非主線資料', '機場系統', '出口', '35586', '33332', '37287'],
#  ['國2西向', '非主線資料', '機場系統', '進口', '46530', '44316', '51332'],
#  ['國2西向', '非主線資料', '南桃園', '出口', '15961', '16754', '19577'],
#  ['國2西向', '非主線資料', '南桃園', '進口', '22932', '22666', '26770'],
#  ['國2西向', '非主線資料', '大湳', '出口', '21815', '21878', '23352'],
#  ['國2西向', '非主線資料', '大湳', '進口', '12073', '10124', '11375'],
#  ['國2西向', '非主線資料', '鶯歌系統', '進口', '57230', '57776', '61021'],
#  ['國3甲東向', '非主線資料', '台北端', '進口', '24855', '21006', '24085'],
#  ['國3甲東向', '非主線資料', '萬芳', '出口', '8015', '7005', '7882'],
#  ['國3甲東向', '非主線資料', '萬芳', '進口1-信義快', '10889', '9207', '11254'],
#  ['國3甲東向', '非主線資料', '萬芳', '進口2-木柵路', '7787', '7075', '6973'],
#  ['國3甲東向', '非主線資料', '深坑端', '出口', '35456', '30231', '34297'],
#  ['國5南向', '非主線資料', '南港系統', '進口', '37081', '30982', '24859'],
#  ['國5南向', '非主線資料', '石碇', '出口', '3711', '4299', '3462'],
#  ['國5南向', '非主線資料', '石碇', '進口', '7463', '4770', '7463'],
#  ['國5南向', '非主線資料', '坪林', '出口', '3680', '3873', '2338'],
#  ['國5南向', '非主線資料', '坪林', '進口', '1559', '880', '1559'],
#  ['國5南向', '非主線資料', '頭城', '出口', '11725', '8846', '7289'],
#  ['國5南向', '非主線資料', '頭城', '進口', '5360', '2736', '5360'],
#  ['國5南向', '非主線資料', '宜蘭', '出口', '14265', '9956', '10113'],
#  ['國5南向', '非主線資料', '宜蘭', '進口', '6875', '5856', '6097'],
#  ['國5南向', '非主線資料', '羅東', '出口', '16810', '11940', '12102'],
#  ['國5南向', '非主線資料', '羅東', '進口', '2983', '2638', '2983'],
#  ['國5南向', '非主線資料', '蘇澳', '出口', '11985', '9552', '9245'],
#  ['國3甲西向', '非主線資料', '台北端', '出口', '23274', '21839', '23970'],
#  ['國3甲西向', '非主線資料', '木柵端', '出口', '9602', '10286', '9016'],
#  ['國3甲西向', '非主線資料', '木柵端', '進口', '25655', '25029', '26414'],
#  ['國3甲西向', '非主線資料', '萬芳', '出口', '19847', '18962', '20588'],
#  ['國3甲西向', '非主線資料', '萬芳', '進口', '7720', '6765', '7764'],
#  ['國3甲西向', '非主線資料', '深坑端', '進口', '18409', '17828', '17806'],
#  ['國5北向', '非主線資料', '南港系統', '出口', '35304', '39959', '26780'],
#  ['國5北向', '非主線資料', '石碇', '出口', '4087', '5081', '3187'],
#  ['國5北向', '非主線資料', '石碇', '進口', '4713', '5170', '3954'],
#  ['國5北向', '非主線資料', '坪林', '出口', '1052', '1204', '866'],
#  ['國5北向', '非主線資料', '坪林', '進口', '3466', '6516', '2523'],
#  ['國5北向', '非主線資料', '頭城', '出口', '5271', '3471', '4738'],
#  ['國5北向', '非主線資料', '頭城', '進口', '10434', '10746', '7572'],
#  ['國5北向', '非主線資料', '宜蘭', '出口', '5438', '3026', '5339'],
#  ['國5北向', '非主線資料', '宜蘭', '進口', '12546', '11808', '10123'],
#  ['國5北向', '非主線資料', '羅東', '出口', '2993', '1797', '3002'],
#  ['國5北向', '非主線資料', '羅東', '進口', '13690', '11737', '11379'],
#  ['國5北向', '非主線資料', '蘇澳', '進口', '10269', '9518', '9271'],
#  ['國4東向', '非主線資料', '清水端', '進口', '15268', '14921', '15465'],
#  ['國4東向', '非主線資料', '中港系統', '出口1-國3南', '2580', '2539', '2311'],
#  ['國4東向', '非主線資料', '中港系統', '出口2-國3北', '3768', '3840', '3815'],
#  ['國4東向', '非主線資料', '中港系統', '進口', '11988', '11663', '10715'],
#  ['國4東向', '非主線資料', '神岡', '出口', '3132', '3455', '3263'],
#  ['國4東向', '非主線資料', '神岡', '進口', '7486', '7356', '7362'],
#  ['國4東向', '非主線資料', '台中系統', '出口', '16019', '16775', '18201'],
#  ['國4東向', '非主線資料', '台中系統', '進口', '16139', '14067', '14578'],
#  ['國4東向', '非主線資料', '后豐', '出口', '9899', '9107', '11279'],
#  ['國4東向', '非主線資料', '豐原端', '出口', '16345', '14893', '13473'],
#  ['國8東向', '非主線資料', '台南端', '進口', '11731', '12012', '10948'],
#  ['國8東向', '非主線資料', '新吉', '進口', '11591', '10599', '11359'],
#  ['國8東向', '非主線資料', '台南系統', '出口', '14420', '14223', '14205'],
#  ['國8東向', '非主線資料', '台南系統', '進口', '16175', '15799', '14894'],
#  ['國8東向', '非主線資料', '新市', '出口', '8462', '7861', '12553'],
#  ['國8東向', '非主線資料', '新市', '進口', '2596', '2811', '3019'],
#  ['國8東向', '非主線資料', '新化系統', '出口', '17503', '18255', '11939'],
#  ['國8東向', '非主線資料', '新化系統', '進口', '2796', '3187', '2348'],
#  ['國8東向', '非主線資料', '新化端', '出口', '4762', '4749', '4340'],
#  ['國4西向', '非主線資料', '清水端', '出口', '15457', '13751', '15068'],
#  ['國4西向', '非主線資料', '中港系統', '出口1-國3北', '11547', '12229', '10797'],
#  ['國4西向', '非主線資料', '中港系統', '出口2-國3南', '4454', '4221', '4234'],
#  ['國4西向', '非主線資料', '中港系統', '進口1-國3南', '4524', '4450', '4296'],
#  ['國4西向', '非主線資料', '中港系統', '進口2-國3北', '2024', '2078', '1876'],
#  ['國4西向', '非主線資料', '神岡', '出口', '6376', '6189', '6892'],
#  ['國4西向', '非主線資料', '神岡', '進口', '2896', '2872', '2871'],
#  ['國4西向', '非主線資料', '台中系統', '出口', '13175', '13643', '13899'],
#  ['國4西向', '非主線資料', '台中系統', '進口', '17992', '17798', '17774'],
#  ['國4西向', '非主線資料', '后豐', '進口', '10998', '11364', '11832'],
#  ['國4西向', '非主線資料', '豐原端', '進口', '14301', '16256', '13382'],
#  ['國8西向', '非主線資料', '台南端', '出口', '9121', '9816', '8666'],
#  ['國8西向', '非主線資料', '新吉', '出口', '11521', '11158', '11342'],
#  ['國8西向', '非主線資料', '台南系統', '出口', '12060', '13109', '13400'],
#  ['國8西向', '非主線資料', '台南系統', '進口', '10072', '10400', '12173'],
#  ['國8西向', '非主線資料', '新市', '出口', '3198', '3813', '3698'],
#  ['國8西向', '非主線資料', '新市', '進口', '10642', '10668', '14319'],
#  ['國8西向', '非主線資料', '新化系統', '出口', '8798', '9442', '4173'],
#  ['國8西向', '非主線資料', '新化系統', '進口', '15344', '17746', '8255'],
#  ['國8西向', '非主線資料', '新化端', '進口', '8520', '8569', '8442'],
#  ['國6東向', '非主線資料', '霧峰系統', '進口', '24729', '21281', '14930'],
#  ['國6東向', '非主線資料', '舊正', '進口', '3710', '2964', '2226'],
#  ['國6東向', '非主線資料', '東草屯', '出口', '3775', '3276', '3462'],
#  ['國6東向', '非主線資料', '東草屯', '進口', '1291', '1229', '1096'],
#  ['國6東向', '非主線資料', '國姓', '出口', '3084', '2400', '1746'],
#  ['國6東向', '非主線資料', '國姓', '進口', '470', '432', '380'],
#  ['國6東向', '非主線資料', '北山', '出口', '931', '683', '402'],
#  ['國6東向', '非主線資料', '愛蘭', '出口', '11890', '10358', '7071'],
#  ['國6東向', '非主線資料', '愛蘭', '進口', '440', '481', '339'],
#  ['國6東向', '非主線資料', '埔里', '出口', '4751', '4474', '3352'],
#  ['國6東向', '非主線資料', '埔里端', '出口', '5753', '4500', '2798'],
#  ['國10東向', '非主線資料', '左營端', '進口1-都會快', '18023', '18048', '17204'],
#  ['國10東向', '非主線資料', '左營端', '進口2-文自路', '16084', '14630', '14565'],
#  ['國10東向', '非主線資料', '鼎金系統', '出口', '24260', '22907', '23365'],
#  ['國10東向', '非主線資料', '鼎金系統', '進口1-國1南', '8960', '8120', '8596'],
#  ['國10東向', '非主線資料', '鼎金系統', '進口2-國1北', '22620', '20983', '20987'],
#  ['國10東向', '非主線資料', '仁武', '出口', '17572', '15328', '17815'],
#  ['國10東向', '非主線資料', '仁武', '進口', '13429', '12506', '12379'],
#  ['國10東向', '非主線資料', '燕巢', '出口', '6097', '6300', '7330'],
#  ['國10東向', '非主線資料', '燕巢', '進口', '9400', '8614', '8645'],
#  ['國10東向', '非主線資料', '燕巢系統', '出口', '22466', '21959', '17110'],
#  ['國10東向', '非主線資料', '燕巢系統', '進口1-國3南', '5482', '4046', '3230'],
#  ['國10東向', '非主線資料', '燕巢系統', '進口2-國3北', '1404', '1846', '1197'],
#  ['國10東向', '非主線資料', '嶺口', '出口', '9654', '8739', '8156'],
#  ['國10東向', '非主線資料', '旗山端', '出口', '14864', '15360', '10270'],
#  ['國6西向', '非主線資料', '霧峰系統', '出口', '23486', '26633', '17200'],
#  ['國6西向', '非主線資料', '舊正', '出口', '2784', '4950', '2269'],
#  ['國6西向', '非主線資料', '東草屯', '出口', '1035', '1746', '979'],
#  ['國6西向', '非主線資料', '東草屯', '進口', '3597', '3461', '3479'],
#  ['國6西向', '非主線資料', '國姓', '出口', '483', '651', '405'],
#  ['國6西向', '非主線資料', '國姓', '進口', '3193', '4232', '2358'],
#  ['國6西向', '非主線資料', '北山', '進口', '741', '1502', '518'],
#  ['國6西向', '非主線資料', '愛蘭', '出口', '362', '478', '250'],
#  ['國6西向', '非主線資料', '愛蘭', '進口', '10466', '12667', '7298'],
#  ['國6西向', '非主線資料', '埔里', '進口', '4507', '6304', '3600'],
#  ['國6西向', '非主線資料', '埔里端', '進口', '4156', '6180', '2844'],
#  ['國10西向', '非主線資料', '左營端', '出口1', '19977', '19721', '18812'],
#  ['國10西向', '非主線資料', '左營端', '出口2-都會快', '18309', '20103', '19867'],
#  ['國10西向', '非主線資料', '鼎金系統', '出口1', '25019', '27574', '22953'],
#  ['國10西向', '非主線資料', '鼎金系統', '出口2-大中二路', '12253', '12013', '11289'],
#  ['國10西向', '非主線資料', '鼎金系統', '進口1-國1北', '27598', '25508', '22540'],
#  ['國10西向', '非主線資料', '鼎金系統', '進口2-國1南', '18881', '17631', '16865'],
#  ['國10西向', '非主線資料', '仁武', '出口', '8157', '9069', '8268'],
#  ['國10西向', '非主線資料', '仁武', '進口', '18097', '16043', '18603'],
#  ['國10西向', '非主線資料', '燕巢', '出口', '8818', '9679', '8040'],
#  ['國10西向', '非主線資料', '燕巢', '進口', '6708', '5584', '9590'],
#  ['國10西向', '非主線資料', '燕巢系統', '出口', '4612', '4647', '3906'],
#  ['國10西向', '非主線資料', '燕巢系統', '進口1-國3南', '6515', '8890', '6517'],
#  ['國10西向', '非主線資料', '燕巢系統', '進口2-國3北', '10822', '13415', '11181'],
#  ['國10西向', '非主線資料', '嶺口', '進口', '5196', '5680', '4242'],
#  ['國10西向', '非主線資料', '旗山端', '進口', '12946', '17106', '10412']]
